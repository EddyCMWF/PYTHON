# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize']=(20,12)
# %matplotlib inline

# %%
BCfile='/users/eow/edwcom/WFD_EI/qrparm.soil_HWSD_cont_cosbyNew.nc'
VGfile='/users/eow/edwcom/WFD_EI/qrparm.soil_HWSD_class3_van_genuchtenNew.nc'
latlonfile='/users/eow/edwcom/WFD_EI/EI-Halfdeg-land-elevation.nc'

# %%
BCinf=nc.Dataset(BCfile,'r')
BCdata={}
UMvars=['field1381','field342','field333','field332','field330','field329','field335','field336','field1395']
BCvars=['b','sathh','satcon','sm_sat','sm_crit','sm_wilt','hcap','hcon','albsoil']
for UMvar,var in zip(UMvars,BCvars):
    BCdata[var]=BCinf.variables[str(UMvar)][:]
BCinf.close()

# %%
VGinf=nc.Dataset(VGfile,'r')
VGdata={}
UMvars=['field1381','field342','field333','field332','field330','field329','field335','field336','field1395']
VGvars=['b','sathh','satcon','sm_sat','sm_crit','sm_wilt','hcap','hcon','albsoil']
for UMvar,var in zip(UMvars,VGvars):
    VGdata[var]=VGinf.variables[str(UMvar)][:]
VGinf.close()

# %%
LLinf=nc.Dataset(latlonfile,'r')
lat=LLinf.variables['longitude'][:]
lon=LLinf.variables['latitude'][:]

# %%
FIG,AXES=plt.subplots(nrows=3, ncols=3, figsize=(20,15))

for AX,var in zip(AXES.flat,BCvars):
    AX.hist(BCdata[var])
    AX.set_title(var)

FIG.suptitle('Brookes and COrey Soil Property Distributions',fontsize=25)

# %%
FIG,AXES=plt.subplots(nrows=3, ncols=3, figsize=(20,15))

for AX,var in zip(AXES.flat,VGvars):
    AX.hist(VGdata[var])
    AX.set_title(var)

FIG.suptitle('Van Genuchten Soil Property Distributions',fontsize=25)

# %%
print(AXES[i])
# Out:
# [<matplotlib.axes._subplots.AxesSubplot object at 0x7f33edc2d1d0>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x7f33ede1e9b0>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x7f33edbfbef0>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x7f33edbd09b0>
#  <matplotlib.axes._subplots.AxesSubplot object at 0x7f33edc261d0>]

# %%
site_lat,site_lon=38.9,-120.633

site_index=np.argmin( np.absolute(lat-site_lat)+np.absolute(lon-site_lon) )

print(site_index)
# Out:
# 37981

# %%
for var,UMvar in zip(VGvars,UMvars):
    print(UMvar, var, VGdata[var][site_index])
# Out:
# field1381 b 6.6313
# field342 sathh 0.396731
# field333 satcon 0.002773
# field332 sm_sat 0.4581
# field330 sm_crit 0.328321
# field329 sm_wilt 0.186614
# field335 hcap 1.18579e+06
# field336 hcon 0.22692
# field1395 albsoil 0.17

# %%
for var,UMvar in zip(BCvars,UMvars):
    print(UMvar, var, BCdata[var][site_index])
# Out:
# field1381 b 6.63
# field342 sathh 0.396735
# field333 satcon 0.00277332
# field332 sm_sat 0.45815
# field330 sm_crit 0.331882
# field329 sm_wilt 0.186628
# field335 hcap 1.18568e+06
# field336 hcon 0.226873
# field1395 albsoil 0.17
